# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Download the data from the above link. How many ".csv" files are available in the dataset?
#       ANS:-->
#               There are 4 csv files in this link.
#               4 csv files are:--->
#                       1.links
#                       2.movies
#                       3.ratings
#                       4.tags

# %%
mov=pd.read_csv(r"C:\Users\mitra\Desktop\INNOMATICS HACKATHONS\DATA SETS\movies.csv")

# %%
mov
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
mov.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
rat=pd.read_csv(r"C:\Users\mitra\Desktop\INNOMATICS HACKATHONS\DATA SETS\ratings.csv")

# %%
rat
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
rat.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
tag=pd.read_csv(r"C:\Users\mitra\Desktop\INNOMATICS HACKATHONS\DATA SETS\tags.csv")

# %%
tag
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
tag.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
df1=pd.merge(mov,tag,on="movieId")

# %%
df1
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# ...

# %% [markdown]
# ###

# %%
df=pd.merge(mov,rat,on="movieId") # Merge using Common Column

# %%
df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %% [markdown]
# ###

# %% [markdown]
# ### What is the shape of "movies.csv"?

# %%
mov.shape # Shape of the movies.csv
# Out:
# (9742, 3)

# %% [markdown]
# ### What is the shape of "ratings.csv"?

# %%
rat.shape # Shape of the rating.csv
# Out:
# (100836, 4)

# %% [markdown]
# ### How many unique "userId" are available in "ratings.csv"?

# %%
rat['userId'].nunique() # Total Unique_ids in rating.csv
# Out:
# 610

# %% [markdown]
# ### Which movie has recieved maximum number of user ratings?

# %%
cmr=df.groupby("title")['rating'].count()

# %%
cmr.idxmax()
# Out:
# 'Forrest Gump (1994)'

# %%
cmr.max()
# Out:
# 329

# %% [markdown]
# ### Select all the correct tags submitted by users to "Matrix, The (1999)" movie?

# %%
df1
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# ...

# %%
df1[df1["title"]=="Matrix, The (1999)"]
# Out:
#       movieId               title                  genres  userId  \
# 1313     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1314     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1315     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     474
# 1316     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 1317     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
#
#                      tag   timestamp
# 1313        martial arts  1457842912
# 1314              sci-fi  1457842899
# 1315  alternate universe  1137204991
# 1316          philosophy  1424141098
# 1317    post apocalyptic  1424141101

# %%
df1[df1["title"]=="Matrix, The (1999)"]["tag"]
# Out:
# 1313          martial arts
# 1314                sci-fi
# 1315    alternate universe
# 1316            philosophy
# 1317      post apocalyptic
# Name: tag, dtype: object

# %% [markdown]
# ### What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"?

# %%
df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
df[df["title"]=="Terminator 2: Judgment Day (1991)"]["rating"].mean() # Average user rating
# Out:
# 3.970982142857143

# %% [markdown]
# ### How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?

# %%
dst=df[df["title"]=="Fight Club (1999)"]["rating"]

# %%
sns.distplot(dst)
plt.show()
# Out:
# C:\Users\mitra\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### THE DATA LOOKS LIKE RIGHT SKEWED

# %% [markdown]
# # 🟢 IMPORTANT NOTE 1 🟢
# Now that you have a good enough understanding of the given data, apply the "Mandatory Operation" given below before solving any of the following questions.

# %% [markdown]
# ## Mandatory Operations:
# 1. Group the user ratings based on movieId and apply aggregation operations like count and mean on ratings.
# 2. Apply inner join on dataframe created from movies.csv and the grouped df from step 1.
# 3. Filter only those movies which have more than 50 user ratings (i.e. > 50).
#
# Above steps will make sure that your data contains only those movies which has recieved more than 50 user ratings.

# %% [markdown]
# ### 1. Group the user ratings based on movieId and apply aggregation operations like count and mean on ratings.

# %%
grpo=rat.groupby("movieId")["rating"].agg(["count","mean"]).reset_index()

# %%
grpo
# Out:
#       movieId  count      mean
# 0           1    215  3.920930
# 1           2    110  3.431818
# 2           3     52  3.259615
# 3           4      7  2.357143
# 4           5     49  3.071429
# ...       ...    ...       ...
# 9719   193581      1  4.000000
# 9720   193583      1  3.500000
# 9721   193585      1  3.500000
# 9722   193587      1  3.500000
# 9723   193609      1  4.000000
#
# [9724 rows x 3 columns]

# %%
grpo.columns = ['movieId', 'rating_count', 'rating_mean']

# %%
grpo
# Out:
#       movieId  rating_count  rating_mean
# 0           1           215     3.920930
# 1           2           110     3.431818
# 2           3            52     3.259615
# 3           4             7     2.357143
# 4           5            49     3.071429
# ...       ...           ...          ...
# 9719   193581             1     4.000000
# 9720   193583             1     3.500000
# 9721   193585             1     3.500000
# 9722   193587             1     3.500000
# 9723   193609             1     4.000000
#
# [9724 rows x 3 columns]

# %% [markdown]
# ### 2. Apply inner join on dataframe created from movies.csv and the grouped df from step 1.

# %%
merg_df = pd.merge(mov, grpo, on='movieId', how='inner')

# %%
merg_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9719   193581  Black Butler: Book of the Atlantic (2017)
# 9720   193583               No Game No Life: Zero (2017)
# 9721   193585                               Flint (2017)
# 9722   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9723   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  rating_count  rating_mean
# 0     Adventure|Animation|Children|Comedy|Fantasy           215     3.920930
# 1                      Adventure|Children|Fantasy           110     3.431818
# ...

# %% [markdown]
# ### 3. Filter only those movies which have more than 50 user ratings (i.e. > 50).

# %%
mov_mor_50= merg_df[merg_df['rating_count'] > 50]

# %%
mov_mor_50
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8287   106782   Wolf of Wall Street, The (2013)
# 8354   109374  Grand Budapest Hotel, The (2014)
# 8358   109487               Interstellar (2014)
# 8457   112852    Guardians of the Galaxy (2014)
# 8673   122904                   Deadpool (2016)
#
#                                            genres  rating_count  rating_mean
# 0     Adventure|Animation|Children|Comedy|Fantasy           215     3.920930
# 1                      Adventure|Children|Fantasy           110     3.431818
# 2                                  Comedy|Romance            52     3.259615
# 5                           Action|Crime|Thriller           102     3.946078
# ...

# %% [markdown]
# ### Which movie is the most popular based on  average user ratings?

# %%
s=merg_df.groupby("title")['rating_mean'].mean()

# %%
most_popular_movie=mov_mor_50[mov_mor_50['rating_count'] > 50].nlargest(1, 'rating_mean')

# %%
most_popular_movie
# Out:
#      movieId                             title       genres  rating_count  \
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama           317
#
#      rating_mean
# 277     4.429022

# %% [markdown]
# ### Select all the correct options which comes under top 5 popular movies based on number of user ratings.

# %%
top_5_popular_movies=mov_mor_50.nlargest(5, 'rating_count')

# %%
top_5_popular_movies
# Out:
#       movieId                             title                       genres  \
# 314       356               Forrest Gump (1994)     Comedy|Drama|Romance|War
# 277       318  Shawshank Redemption, The (1994)                  Crime|Drama
# 257       296               Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 510       593  Silence of the Lambs, The (1991)        Crime|Horror|Thriller
# 1938     2571                Matrix, The (1999)       Action|Sci-Fi|Thriller
#
#       rating_count  rating_mean
# 314            329     4.164134
# 277            317     4.429022
# 257            307     4.197068
# 510            279     4.161290
# 1938           278     4.192446

# %% [markdown]
# ### Which Sci-Fi movie is "third most popular" based on the number of user ratings?

# %%
sci_fi_movies = mov_mor_50[mov_mor_50['genres'].str.contains('Sci-Fi')]

# %%
sorted_sci_fi_movies = sci_fi_movies.sort_values(by='rating_count', ascending=False)

# %%
third_most_popular_sci_fi_movie = sorted_sci_fi_movies.iloc[2]

# %%
third_most_popular_sci_fi_movie
# Out:
# movieId                                      480
# title                       Jurassic Park (1993)
# genres          Action|Adventure|Sci-Fi|Thriller
# rating_count                                 238
# rating_mean                                 3.75
# Name: 418, dtype: object

# %% [markdown]
# # 🟢 IMPORTANT NOTE 2 🟢
# You already have a subset of data containing only those movies which has recieved more than 50 user ratings.
#
# Using "links.csv", scrape the IMDB reviews of each movie with more than 50 user ratings. "README.md" file contains the required details.

# %%
dfw=pd.read_csv(r"C:\Users\mitra\Desktop\INNOMATICS HACKATHONS\DATA SETS\links.csv")

# %% [markdown]
# ## WEB-SCRAPING

# %%
import requests
import numpy as np
from bs4 import BeautifulSoup

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL, headers=request_header)
    soup = BeautifulSoup(response.text)
    imdb_rating = soup.find('span', attrs={"class" : "sc-bde20123-1 cMEQkK"})
    return imdb_rating.text if imdb_rating else np.nan

# %%
imdb_ratings = []
for i in dfw['imdbId']:
    imdb_ratings.append(scrapper(i))

# %%
df_link = pd.merge(mov_mor_50, links_df, on='movieId', how='inner')

# %%
# Changing the data type from object to int

df_link['imdb_rating'] = df_link['imdb_rating'].astype('float')

# %% [markdown]
# ### Mention the movieId of the movie which has the highest IMDB rating.

# %%
highest_imdb_rating_movie = df_link.nlargest(1, 'imdb_rating')
print(highest_imdb_rating_movie[['movieId', 'title', 'imdb_rating']])

# %% [markdown]
# ### Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.

# %%
highest_scifi_rating_movie = df_link[df_link['genres'].str.contains('Sci-Fi')].nlargest(1, 'imdb_rating')
print(highest_scifi_rating_movie[['movieId', 'title', 'imdb_rating']])
