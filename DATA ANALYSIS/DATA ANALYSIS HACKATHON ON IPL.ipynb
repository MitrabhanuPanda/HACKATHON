# %% [markdown]
# # <font color="Green"> IPL DATA ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"matches.csv")

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df2=pd.read_csv(r"deliveries.csv")

# %%
df2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %% [markdown]
# ## <font color="red"> 1. Which of the following is the right way to merge 2 datasets for getting better insights from the data?

# %%
df_act=pd.merge(left=df2,right=df,left_on=df2.match_id,right_on=df.id)

# %%
df_act
# Out:
#         key_0  match_id  inning         batting_team  \
# 0           1         1       1  Sunrisers Hyderabad
# 1           1         1       1  Sunrisers Hyderabad
# 2           1         1       1  Sunrisers Hyderabad
# 3           1         1       1  Sunrisers Hyderabad
# 4           1         1       1  Sunrisers Hyderabad
# ...       ...       ...     ...                  ...
# 179073  11415     11415       2  Chennai Super Kings
# 179074  11415     11415       2  Chennai Super Kings
# 179075  11415     11415       2  Chennai Super Kings
# 179076  11415     11415       2  Chennai Super Kings
# 179077  11415     11415       2  Chennai Super Kings
#
#                        bowling_team  over  ball    batsman non_striker  \
# 0       Royal Challengers Bangalore     1     1  DA Warner    S Dhawan
# 1       Royal Challengers Bangalore     1     2  DA Warner    S Dhawan
# 2       Royal Challengers Bangalore     1     3  DA Warner    S Dhawan
# ...

# %%
df_act.columns
# Out:
# Index(['key_0', 'match_id', 'inning', 'batting_team', 'bowling_team', 'over',
#        'ball', 'batsman', 'non_striker', 'bowler', 'is_super_over',
#        'wide_runs', 'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3'],
#       dtype='object')

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red">2. The column which has the most missing values according to the data is:

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# #### <font color="Blue">The column which has the most missing values according to the data is:--> umpire3

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red">3. City which hosted most number of seasons according to the data is:

# %%
gb=df.groupby("season")

# %%
gb.get_group(2009)
# Out:
#       id  season            city        date                        team1  \
# 117  118    2009       Cape Town  2009-04-18               Mumbai Indians
# 118  119    2009       Cape Town  2009-04-18  Royal Challengers Bangalore
# 119  120    2009       Cape Town  2009-04-19              Kings XI Punjab
# 120  121    2009       Cape Town  2009-04-19        Kolkata Knight Riders
# 121  122    2009  Port Elizabeth  2009-04-20          Chennai Super Kings
# 122  123    2009          Durban  2009-04-21              Kings XI Punjab
# 123  124    2009       Cape Town  2009-04-22              Deccan Chargers
# 124  125    2009          Durban  2009-04-23             Delhi Daredevils
# 125  126    2009       Cape Town  2009-04-23             Rajasthan Royals
# 126  127    2009          Durban  2009-04-24  Royal Challengers Bangalore
# 127  128    2009          Durban  2009-04-25              Deccan Chargers
# 128  129    2009  Port Elizabeth  2009-04-26  Royal Challengers Bangalore
# ...

# %%
gb.get_group(2009).max()
# Out:
# id                                         174
# season                                    2009
# city                            Port Elizabeth
# date                                2009-05-24
# team1              Royal Challengers Bangalore
# team2              Royal Challengers Bangalore
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# result                                     tie
# dl_applied                                   1
# winner             Royal Challengers Bangalore
# win_by_runs                                 92
# win_by_wickets                              10
# player_of_match                   Yuvraj Singh
# venue                          SuperSport Park
# umpire1                              SS Hazare
# umpire2                         TH Wijewardene
# umpire3                                   None
# dtype: object

# %%
l=gb.get_group(2009).city.value_counts()

# %%
l
# Out:
# Durban            15
# Centurion         12
# Johannesburg       8
# Cape Town          7
# Port Elizabeth     7
# East London        3
# Kimberley          3
# Bloemfontein       2
# Name: city, dtype: int64

# %%
k=gb.get_group(2008).city.value_counts()

# %%
k
# Out:
# Mumbai        10
# Bangalore      7
# Chandigarh     7
# Kolkata        7
# Jaipur         7
# Hyderabad      7
# Chennai        7
# Delhi          6
# Name: city, dtype: int64

# %%
j=gb.get_group(2010).city.value_counts()

# %%
j
# Out:
# Mumbai        13
# Kolkata        7
# Chennai        7
# Bangalore      7
# Delhi          7
# Chandigarh     5
# Ahmedabad      4
# Nagpur         3
# Jaipur         3
# Cuttack        2
# Dharamsala     2
# Name: city, dtype: int64

# %%
i=gb.get_group(2011).city.value_counts()

# %%
i
# Out:
# Mumbai        16
# Chennai        9
# Hyderabad      7
# Delhi          7
# Kolkata        7
# Jaipur         7
# Bangalore      6
# Kochi          5
# Chandigarh     4
# Dharamsala     3
# Indore         2
# Name: city, dtype: int64

# %%
h=gb.get_group(2012).city.value_counts()

# %%
h
# Out:
# Chennai          10
# Pune              9
# Mumbai            8
# Jaipur            8
# Bangalore         8
# Delhi             8
# Kolkata           7
# Chandigarh        6
# Hyderabad         4
# Visakhapatnam     2
# Cuttack           2
# Dharamsala        2
# Name: city, dtype: int64

# %%
g=gb.get_group(2013).city.value_counts()

# %%
g
# Out:
# Kolkata       8
# Bangalore     8
# Hyderabad     8
# Delhi         8
# Chennai       8
# Pune          8
# Jaipur        8
# Mumbai        8
# Chandigarh    6
# Dharamsala    2
# Raipur        2
# Ranchi        2
# Name: city, dtype: int64

# %%
f=gb.get_group(2014).city.value_counts()

# %%
f
# Out:
# Abu Dhabi     7
# Mumbai        7
# Sharjah       6
# Bangalore     6
# Delhi         5
# Ranchi        4
# Ahmedabad     4
# Hyderabad     4
# Kolkata       4
# Cuttack       3
# Chandigarh    3
# Name: city, dtype: int64

# %%
e=gb.get_group(2015).city.value_counts()

# %%
e
# Out:
# Mumbai           11
# Kolkata           7
# Chennai           7
# Bangalore         7
# Delhi             5
# Pune              4
# Ahmedabad         4
# Chandigarh        4
# Hyderabad         4
# Visakhapatnam     3
# Raipur            2
# Ranchi            1
# Name: city, dtype: int64

# %%
d=gb.get_group(2016).city.value_counts()

# %%
d
# Out:
# Bangalore        9
# Kolkata          7
# Chandigarh       7
# Delhi            7
# Hyderabad        7
# Visakhapatnam    6
# Rajkot           5
# Mumbai           4
# Pune             4
# Kanpur           2
# Raipur           2
# Name: city, dtype: int64

# %%
c=gb.get_group(2017).city.value_counts()

# %%
c
# Out:
# Hyderabad     8
# Bangalore     8
# Mumbai        8
# Pune          7
# Kolkata       7
# Delhi         7
# Rajkot        5
# Chandigarh    4
# Indore        3
# Kanpur        2
# Name: city, dtype: int64

# %%
b=gb.get_group(2018).city.value_counts()

# %%
b
# Out:
# Mumbai       9
# Kolkata      9
# Hyderabad    7
# Jaipur       7
# Bengaluru    7
# Delhi        7
# Pune         6
# Indore       4
# Mohali       3
# Chennai      1
# Name: city, dtype: int64

# %%
a=gb.get_group(2019).city.value_counts()

# %%
a
# Out:
# Chennai          8
# Hyderabad        8
# Kolkata          7
# Mumbai           7
# Jaipur           7
# Delhi            7
# Bengaluru        7
# Mohali           7
# Visakhapatnam    2
# Name: city, dtype: int64

# %%
a["Mumbai"]+b["Mumbai"]+c["Mumbai"]+d["Mumbai"]+e["Mumbai"]+f["Mumbai"]+g["Mumbai"]+h["Mumbai"]+i["Mumbai"]+j["Mumbai"]+k["Mumbai"]
# Out:
# 101

# %%
a["Delhi"]+b["Delhi"]+c["Delhi"]+d["Delhi"]+e["Delhi"]+f["Delhi"]+g["Delhi"]+h["Delhi"]+i["Delhi"]+j["Delhi"]+k["Delhi"]
# Out:
# 74

# %%
a["Bengaluru"]+b["Bengaluru"]+c["Bangalore"]+d["Bangalore"]+e["Bangalore"]+f["Bangalore"]+g["Bangalore"]+h["Bangalore"]+i["Bangalore"]+j["Bangalore"]+k["Bangalore"]
# Out:
# 80

# %%
a["Bengaluru"]+b["Bengaluru"]
# Out:
# 14

# %% [markdown]
# #### <font color="Blue">City Mumbai hosted most number of seasons according to the data is

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red">4. Which year has the most number of matches played?

# %%
len(gb.get_group(2011))
# Out:
# 73

# %%
len(gb.get_group(2013))
# Out:
# 76

# %%
len(gb.get_group(2019))
# Out:
# 60

# %%
len(gb.get_group(2014))
# Out:
# 60

# %% [markdown]
# #### <font color="Blue">In 2013 year has the most number of matches played

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 5. Maximum wins by Mumbai Indians in 2011 are

# %%
gb.get_group(2011)
# Out:
#       id  season       city        date                        team1  \
# 234  235    2011    Chennai  2011-04-08          Chennai Super Kings
# 235  236    2011  Hyderabad  2011-04-09              Deccan Chargers
# 236  237    2011      Kochi  2011-04-09         Kochi Tuskers Kerala
# 237  238    2011      Delhi  2011-04-10             Delhi Daredevils
# 238  239    2011     Mumbai  2011-04-10              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 302  303    2011    Kolkata  2011-05-22        Kolkata Knight Riders
# 303  304    2011     Mumbai  2011-05-24  Royal Challengers Bangalore
# 304  305    2011     Mumbai  2011-05-25        Kolkata Knight Riders
# 305  306    2011    Chennai  2011-05-27  Royal Challengers Bangalore
# 306  307    2011    Chennai  2011-05-28          Chennai Super Kings
#
#                            team2           toss_winner toss_decision  result  \
# ...

# %%
gb.get_group(2011)["winner"].value_counts()
# Out:
# Chennai Super Kings            11
# Royal Challengers Bangalore    10
# Mumbai Indians                 10
# Kolkata Knight Riders           8
# Kings XI Punjab                 7
# Rajasthan Royals                6
# Deccan Chargers                 6
# Kochi Tuskers Kerala            6
# Pune Warriors                   4
# Delhi Daredevils                4
# Name: winner, dtype: int64

# %% [markdown]
# #### <font color="Blue">Maximum wins by Mumbai Indians in 2011 are:--> 10

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 6. For 'toss_decision' feature what kind of plot is suitable?

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df["toss_decision"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
df["toss_decision"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["toss_decision"].value_counts().plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <font color="Blue">For 'toss_decision' feature Bar Plot, Pie Plot kind of plot is suitable

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 7.  What is the percentage of getting bat and field in feature 'toss_descision'?

# %%
df["toss_decision"].value_counts().plot(kind="pie",autopct="%0.2F%%")
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %% [markdown]
# #### <font color="Blue">(61.24%, 38.76%) is the percentage of getting bat and field in feature 'toss_descision'?

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 8.  Which statement holds true

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df4=df.drop(['city', 'date', 'team1', 'team2',
        'result', 'dl_applied', 'win_by_runs',
       'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
     'umpire3'],axis=1)

# %%
df4
# Out:
#         id  season                  toss_winner toss_decision  \
# 0        1    2017  Royal Challengers Bangalore         field
# 1        2    2017       Rising Pune Supergiant         field
# 2        3    2017        Kolkata Knight Riders         field
# 3        4    2017              Kings XI Punjab         field
# 4        5    2017  Royal Challengers Bangalore           bat
# ..     ...     ...                          ...           ...
# 751  11347    2019               Mumbai Indians         field
# 752  11412    2019          Chennai Super Kings           bat
# 753  11413    2019               Delhi Capitals         field
# 754  11414    2019          Chennai Super Kings         field
# 755  11415    2019               Mumbai Indians           bat
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
r=df4[df4["toss_winner"]==df4["winner"]]

# %%
r
# Out:
#         id  season                  toss_winner toss_decision  \
# 1        2    2017       Rising Pune Supergiant         field
# 2        3    2017        Kolkata Knight Riders         field
# 3        4    2017              Kings XI Punjab         field
# 4        5    2017  Royal Challengers Bangalore           bat
# 5        6    2017          Sunrisers Hyderabad         field
# ..     ...     ...                          ...           ...
# 750  11346    2019              Kings XI Punjab         field
# 751  11347    2019               Mumbai Indians         field
# 753  11413    2019               Delhi Capitals         field
# 754  11414    2019          Chennai Super Kings         field
# 755  11415    2019               Mumbai Indians           bat
#
#                           winner
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# 5            Sunrisers Hyderabad
# ...

# %%
r[r["toss_decision"]=="field"]
# Out:
#         id  season                  toss_winner toss_decision  \
# 1        2    2017       Rising Pune Supergiant         field
# 2        3    2017        Kolkata Knight Riders         field
# 3        4    2017              Kings XI Punjab         field
# 5        6    2017          Sunrisers Hyderabad         field
# 6        7    2017               Mumbai Indians         field
# ..     ...     ...                          ...           ...
# 749  11345    2019  Royal Challengers Bangalore         field
# 750  11346    2019              Kings XI Punjab         field
# 751  11347    2019               Mumbai Indians         field
# 753  11413    2019               Delhi Capitals         field
# 754  11414    2019          Chennai Super Kings         field
#
#                           winner
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 5            Sunrisers Hyderabad
# 6                 Mumbai Indians
# ...

# %%
r[r["toss_decision"]=="bat"]
# Out:
#         id  season                  toss_winner toss_decision  \
# 4        5    2017  Royal Challengers Bangalore           bat
# 14      15    2017             Delhi Daredevils           bat
# 20      21    2017          Sunrisers Hyderabad           bat
# 50      51    2017             Delhi Daredevils           bat
# 54      55    2017  Royal Challengers Bangalore           bat
# ..     ...     ...                          ...           ...
# 713  11309    2019          Chennai Super Kings           bat
# 729  11325    2019               Mumbai Indians           bat
# 741  11337    2019               Delhi Capitals           bat
# 746  11342    2019               Mumbai Indians           bat
# 755  11415    2019               Mumbai Indians           bat
#
#                           winner
# 4    Royal Challengers Bangalore
# 14              Delhi Daredevils
# 20           Sunrisers Hyderabad
# 50              Delhi Daredevils
# 54   Royal Challengers Bangalore
# ...

# %% [markdown]
# #### <font color="Blue"> Teams winning tosses and electing field first have won more number of matches.

# %% [markdown]
# ## <font color="red"> 9. In which years where taking batting second have won more number of matches?

# %%
e=r[r["toss_decision"]=="field"]

# %%
e
# Out:
#         id  season                  toss_winner toss_decision  \
# 1        2    2017       Rising Pune Supergiant         field
# 2        3    2017        Kolkata Knight Riders         field
# 3        4    2017              Kings XI Punjab         field
# 5        6    2017          Sunrisers Hyderabad         field
# 6        7    2017               Mumbai Indians         field
# ..     ...     ...                          ...           ...
# 749  11345    2019  Royal Challengers Bangalore         field
# 750  11346    2019              Kings XI Punjab         field
# 751  11347    2019               Mumbai Indians         field
# 753  11413    2019               Delhi Capitals         field
# 754  11414    2019          Chennai Super Kings         field
#
#                           winner
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 5            Sunrisers Hyderabad
# 6                 Mumbai Indians
# ...

# %%
e["season"].value_counts()
# Out:
# 2016    32
# 2019    31
# 2017    28
# 2011    27
# 2018    27
# 2014    24
# 2008    19
# 2012    18
# 2013    15
# 2009    14
# 2015    14
# 2010    10
# Name: season, dtype: int64

# %% [markdown]
# #### <font color="Blue"> In (2009,2017),(2015,2019) years where taking batting second have won more number of matches?

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 10. To plot the most consistent batsmen among top 10 run getters, what plotting technique we use?

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df["player_of_match"].value_counts().head(10)
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
sns.countplot(y=df["player_of_match"].value_counts().head(10),data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='player_of_match'>

# %% [markdown]
# #### <font color="Blue">To plot the most consistent batsmen among top 10 run getters, COUNT plotting technique we use

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 11. In 2019 which batsman scored highest number of runs by hitting 6's and 4's?

# %%
df2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df2[df2["batsman"]=="CH Gayle"]
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 125            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 131            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 132            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 133            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 137            1       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# ...          ...     ...                          ...                  ...
# 177820     11346       2              Kings XI Punjab  Chennai Super Kings
# 177821     11346       2              Kings XI Punjab  Chennai Super Kings
# 177822     11346       2              Kings XI Punjab  Chennai Super Kings
# 177825     11346       2              Kings XI Punjab  Chennai Super Kings
# 177827     11346       2              Kings XI Punjab  Chennai Super Kings
#
# ...

# %%
df2[df2["batsman"]=="CH Gayle"]["total_runs"]
# Out:
# 125       1
# 131       0
# 132       0
# 133       1
# 137       0
#          ..
# 177820    2
# 177821    0
# 177822    1
# 177825    1
# 177827    0
# Name: total_runs, Length: 3131, dtype: int64

# %%
sum(df2[df2["batsman"]=="CH Gayle"]["total_runs"])
# Out:
# 4873

# %%
sum(df2[df2["batsman"]=="AD Russell"]["total_runs"])
# Out:
# 1527

# %%
sum(df2[df2["batsman"]=="KL Rahul"]["total_runs"])
# Out:
# 2087

# %%
sum(df2[df2["batsman"]=="DA Warner"]["total_runs"])
# Out:
# 4975

# %% [markdown]
# ### <font color="brown"> Other way

# %%
sum(df2[df2["batsman"]=="CH Gayle"]["batsman_runs"])
# Out:
# 4560

# %%
sum(df2[df2["batsman"]=="AD Russell"]["batsman_runs"])
# Out:
# 1445

# %%
sum(df2[df2["batsman"]=="KL Rahul"]["batsman_runs"])
# Out:
# 2013

# %%
sum(df2[df2["batsman"]=="DA Warner"]["batsman_runs"])
# Out:
# 4741

# %% [markdown]
# #### <font color="Blue">In 2019 DA Warner batsman scored highest number of runs by hitting 6's and 4's?

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 12. Most number of wickets taken by a bowler is:

# %%
df2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df2["player_dismissed"].value_counts()
# Out:
# SK Raina      162
# RG Sharma     155
# RV Uthappa    153
# V Kohli       143
# S Dhawan      137
#              ...
# S Randiv        1
# R Ninan         1
# B Sumanth       1
# C Madan         1
# S Singh         1
# Name: player_dismissed, Length: 487, dtype: int64

# %%
df2["dismissal_kind"].value_counts()
# Out:
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
sum(df2[df2["bowler"]=="SL Malinga"]["dismissal_kind"].value_counts())
# Out:
# 188

# %%
sum(df2[df2["bowler"]=="DJ Bravo"]["dismissal_kind"].value_counts())
# Out:
# 168

# %%
sum(df2[df2["bowler"]=="A Mishra"]["dismissal_kind"].value_counts())
# Out:
# 165

# %%
sum(df2[df2["bowler"]=="Harbhajan Singh"]["dismissal_kind"].value_counts())
# Out:
# 161

# %% [markdown]
# #### <font color="Blue"> Most number of wickets taken by a bowler is:--> SL Malinga

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 13.  What is the strike rate of Kohli in 2016
#
#     HINT: strike rate = (Total Runs / Total Balls Faced) * 100

# %%
df2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
sum(df2[df2["batsman"]=="V Kohli"]["total_runs"])
# Out:
# 5616

# %%
sum(df2[df2["batsman"]=="V Kohli"]["ball"])
# Out:
# 14728

# %%
(sum(df2[df2["batsman"]=="V Kohli"]["total_runs"])/sum(df2[df2["batsman"]=="V Kohli"]["ball"]))*100
# Out:
# 38.13145029875068

# %% [markdown]
# ## <font color="red"> 14.  Bowlers with maximum number of extras:

# %%
sum(df2[df2["bowler"]=="P Kumar"]["extra_runs"])
# Out:
# 236

# %%
sum(df2[df2["bowler"]=="DJ Bravo"]["extra_runs"])
# Out:
# 201

# %%
sum(df2[df2["bowler"]=="SR Watson"]["extra_runs"])
# Out:
# 171

# %%
sum(df2[df2["bowler"]=="SL Malinga"]["extra_runs"])
# Out:
# 293

# %% [markdown]
# #### <font color="Blue"> Bowlers with maximum number of extras:--> SL Malinga

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 15. Which venue has hosted most number of IPL matches?

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df["venue"].value_counts()
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %% [markdown]
# #### <font color="Blue"> In Eden Gardens  venue has hosted most number of IPL matches?

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 16. In 2017 when sunrisers hyderabad clashed against Royal Challengers Bangalore which team player won player of the match?

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df[(df["season"]==2017) & (df["team1"]=="Sunrisers Hyderabad") & (df["team2"]=="Royal Challengers Bangalore")]
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2 umpire3
# 0  NJ Llong     NaN

# %% [markdown]
# #### <font color="Blue">In 2017 when sunrisers hyderabad clashed against Royal Challengers Bangalore, Yuvraj Singh, from Sunrisers Hyderabad team player won player of the match

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 17. Across seasons who are the top three batsman's with most number of run out?

# %%
df2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df2["dismissal_kind"].value_counts()
# Out:
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
len(df2[(df2["batsman"]=="MS Dhoni") & (df2["dismissal_kind"]=="run out")])
# Out:
# 21

# %%
len(df2[(df2["batsman"]=="Y Venugopal Rao") & (df2["dismissal_kind"]=="run out")])
# Out:
# 9

# %%
len(df2[(df2["batsman"]=="S Gill") & (df2["dismissal_kind"]=="run out")])
# Out:
# 1

# %%
len(df2[(df2["batsman"]=="RG Sharma") & (df2["dismissal_kind"]=="run out")])
# Out:
# 17

# %%
len(df2[(df2["batsman"]=="V Kohli") & (df2["dismissal_kind"]=="run out")])
# Out:
# 15

# %% [markdown]
# #### <font color="Blue">Across seasons MS Dhoni,RG Sharma,V Kohli are the top three batsman's with most number of run out?

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 18. What are the total runs scored by V Kohli when the bowler was JJ Burmah?

# %%
df2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df2[(df2["batsman"]=="V Kohli") & (df2["bowler"]=="JJ Bumrah")]
# Out:
#         match_id  inning                 batting_team    bowling_team  over  \
# 2633          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2634          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2635          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2637          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2638          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# ...          ...     ...                          ...             ...   ...
# 166347     11143       2  Royal Challengers Bangalore  Mumbai Indians     4
# 166348     11143       2  Royal Challengers Bangalore  Mumbai Indians     4
# 166349     11143       2  Royal Challengers Bangalore  Mumbai Indians     4
# 166406     11143       2  Royal Challengers Bangalore  Mumbai Indians    14
# 166408     11143       2  Royal Challengers Bangalore  Mumbai Indians    14
#
# ...

# %%
sum(df2[(df2["batsman"]=="V Kohli") & (df2["bowler"]=="JJ Bumrah")]["total_runs"])
# Out:
# 114

# %% [markdown]
# #### <font color="Blue">114  the total runs scored by V Kohli when the bowler was JJ Burmah?

# %% [markdown]
# ###

# %% [markdown]
# ## <font color="red"> 19. Across all seasons which player was dismissed the maximum number of times via caught and bowled

# %%
df2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df2["player_dismissed"].value_counts()
# Out:
# SK Raina      162
# RG Sharma     155
# RV Uthappa    153
# V Kohli       143
# S Dhawan      137
#              ...
# S Randiv        1
# R Ninan         1
# B Sumanth       1
# C Madan         1
# S Singh         1
# Name: player_dismissed, Length: 487, dtype: int64

# %% [markdown]
# #### <font color="Blue">Across all seasons SK RAINA  was dismissed the maximum number of times via caught and bowled

# %% [markdown]
# ###
